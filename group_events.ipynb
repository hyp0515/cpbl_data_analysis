# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# read a CSV into a dataframe (adjust filename as needed)
events_filename = './data/event.csv'  # or provide a full path

if not os.path.exists(events_filename):
    csv_files = [f for f in os.listdir('.') if f.lower().endswith('.csv')]
    if not csv_files:
        raise FileNotFoundError(f"{events_filename!r} not found and no CSV files in the current directory.")
    filename = csv_files[0]
    print(f"No file named 'data.csv' found. Using first CSV in cwd: {filename}")

events = pd.read_csv(events_filename)
print(f"Loaded {len(events)} rows and {len(events.columns)} columns from {events_filename}")
events.head()
# Out:
# Loaded 107738 rows and 14 columns from ./data/event.csv
# /var/folders/_b/sl_t4k5539781f29qf723b080000gn/T/ipykernel_50332/2221732598.py:11: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   events = pd.read_csv(events_filename)
#     type  inPlay  isStrike  isBall pitcherName catcherName batterName  \
# 0  PITCH   False     False    True         徐若熙         蔣少宏        陳晨威
# 1  PITCH    True      True   False         徐若熙         蔣少宏        陳晨威
# 2  PITCH   False      True   False         徐若熙         蔣少宏         林立
# 3  PITCH   False      True   False         徐若熙         蔣少宏         林立
# 4  PITCH   False     False    True         徐若熙         蔣少宏         林立
#
#   pitchCode pitchType velocity  coordX  coordY  \
# 0         B        FF      145   71.11  -91.43
# 1         H        FF      147   54.86   42.67
# 2         F        FF      145   54.86   22.35
# 3        SW        SL      135   -2.03  -56.89
# 4         B        SL      139  -34.54 -144.25
#
#                                              runners  PAId
# 0                                                 []   NaN
# 1  [{'type': 'PA', 'runnerName': '陳晨威', 'isOut': ...   NaN
# 2                                                 []   NaN
# 3                                                 []   NaN
# 4                                                 []   NaN

# %%
# read a CSV into a dataframe (adjust filename as needed)
pa_filename = './data/pa.csv'  # or provide a full path

if not os.path.exists(pa_filename):
    csv_files = [f for f in os.listdir('.') if f.lower().endswith('.csv')]
    if not csv_files:
        raise FileNotFoundError(f"{pa_filename!r} not found and no CSV files in the current directory.")
    filename = csv_files[0]
    print(f"No file named 'data.csv' found. Using first CSV in cwd: {filename}")



pas = pd.read_csv(pa_filename, usecols=['inning', 'batterName', 'batterHand', 'pitcherName', 'pitcherHand', 'catcherName', 'paRound', 'pitchCodes', 'result'])
print(f"Loaded {len(pas)} rows and {len(pas.columns)} columns from {pa_filename}")
pas.drop(columns=['batterHand'], inplace=True)
pas.head()
# Out:
# Loaded 27600 rows and 9 columns from ./data/pa.csv
#    inning batterName pitcherName pitcherHand catcherName  paRound  \
# 0       1        陳晨威         徐若熙           R         蔣少宏        1
# 1       1         林立         徐若熙           R         蔣少宏        1
# 2       1        梁家榮         徐若熙           R         蔣少宏        1
# 3       1        廖健富         徐若熙           R         蔣少宏        1
# 4       2        朱育賢         徐若熙           R         蔣少宏        1
#
#                    pitchCodes result
# 0                  ['B', 'H']     GO
# 1  ['F', 'SW', 'B', 'B', 'S']     SO
# 2        ['S', 'F', 'B', 'H']     2B
# 3                  ['B', 'H']     1B
# 4            ['S', 'SW', 'H']     FO

# %% [markdown]
# # group events with pa

# %%
for pa in pas:
    if pa['result'] != 'IGNORE':
        pitches_info = []
        for event in events:
            if event['type'] == 'PITCH' and event['paRound'] == pa['paRound']:
                pitches_info.append(event)
